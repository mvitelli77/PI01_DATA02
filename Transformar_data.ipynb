# %%
# Creo este script para normalizar y extraer los datos que precio para responder a las Consultas del Trabajo 1
import pandas as pd
import json

# %%
results=pd.read_csv("Datasets/results.csv")

# %%
# Note que hay muchos datos que estan faltantes y otros \N pero no son necesarios para las consultas, por lo que voy a crear una database
# filtrado con las columnas que preciso para mejorar el procesamiento y verifico que estan completas.
results.head(10)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
# 5         6      18         6              3      8    13        6
# 6         7      18         7              5     14    17        7
# 7         8      18         8              6      1    15        8
# 8         9      18         9              2      4     2       \N
# 9        10      18        10              7     12    18       \N
#
#   positionText  positionOrder  points  laps     time milliseconds fastestLap  \
# 0            1              1    10.0    58  34:50.6      5690616         39
# ...

# %%
results_filter=results.loc[:,["driverId","constructorId","raceId","positionOrder","points"]]
results_filter.head()
# Out:
#    driverId  constructorId  raceId  positionOrder  points
# 0         1              1      18              1    10.0
# 1         2              2      18              2     8.0
# 2         3              3      18              3     6.0
# 3         4              4      18              4     5.0
# 4         5              1      18              5     4.0

# %%
# Lo guardo en csv para importarlo con MySQL
results_filter.to_csv('Datasets/results_filtrados.csv')

# %%
results_filter.shape
# Out:
# (24940, 5)

# %%
# Importo el Json que previamente con Notepad++ verifique los [corchetes] y las ,comas,  
constructors=pd.read_json("Datasets/constructors.json")

# %%
constructors.head(20)
# Out:
#     constructorId constructorRef         name nationality  \
# 0               1        mclaren      McLaren     British
# 1               2     bmw_sauber   BMW Sauber      German
# 2               3       williams     Williams     British
# 3               4        renault      Renault      French
# 4               5     toro_rosso   Toro Rosso     Italian
# 5               6        ferrari      Ferrari     Italian
# 6               7         toyota       Toyota    Japanese
# 7               8    super_aguri  Super Aguri    Japanese
# 8               9       red_bull     Red Bull    Austrian
# 9              10    force_india  Force India      Indian
# 10             11          honda        Honda    Japanese
# 11             12         spyker       Spyker       Dutch
# 12             13            mf1          MF1     Russian
# 13             14     spyker_mf1   Spyker MF1       Dutch
# 14             15         sauber       Sauber       Swiss
# ...

# %%
constructors.to_csv('Datasets/constructors_filtrados.csv')
# Lo exporto a csv para importarlo con MySQL
